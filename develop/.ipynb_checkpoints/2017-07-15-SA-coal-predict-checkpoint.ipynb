# %% [markdown]
# # Make a coal production prediction

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set();

# %%
df = pd.read_csv("../data/cleaned_coalpublic2013.csv", index_col='MSHA ID')
df.head()
# Out:
#          Year                       Mine_Name Mine_State Mine_County  \
# MSHA ID
# 103381   2013            Tacoa Highwall Miner    Alabama        Bibb
# 103404   2013                Reid School Mine    Alabama      Blount
# 100759   2013  North River #1 Underground Min    Alabama     Fayette
# 103246   2013                      Bear Creek    Alabama    Franklin
# 103451   2013                     Knight Mine    Alabama    Franklin
#
#                                 Mine_Status    Mine_Type  \
# MSHA ID
# 103381   Active, men working, not producing      Surface
# 103404                Permanently abandoned      Surface
# 100759   Active, men working, not producing  Underground
# 103246                               Active      Surface
# 103451                               Active      Surface
#
#                           Company_Type              Operation_Type  \
# MSHA ID
# 103381   Independent Producer Operator                   Mine only
# ...

# %%
len(df)
# Out:
# 1061

# %%
for column in df.columns:
    print(column)
# Out:
# Year
# Mine_Name
# Mine_State
# Mine_County
# Mine_Status
# Mine_Type
# Company_Type
# Operation_Type
# Operating_Company
# Operating_Company_Address
# Union_Code
# Coal_Supply_Region
# Production_(short_tons)
# Average_Employees
# Labor_Hours
# log_production

# %%
df.log_production.hist()  # if the plot tells a story well leave and style it better else delete in deliver notebook

# %%
df.Mine_Status.unique()
# Out:
# array(['Active, men working, not producing', 'Permanently abandoned',
#        'Active', 'Temporarily closed', 'New, under construction'], dtype=object)

# %%
df[['Mine_Status','Production_(short_tons)']].groupby('Mine_Status').mean()
# Out:
#                                     Production_(short_tons)
# Mine_Status
# Active                                         1.283471e+06
# Active, men working, not producing             1.259756e+05
# New, under construction                        5.200000e+01
# Permanently abandoned                          6.050497e+04
# Temporarily closed                             2.966640e+04

# %%
df[['Mine_Status','log_production']].groupby('Mine_Status').mean()
# Out:
#                                     log_production
# Mine_Status
# Active                                   11.977453
# Active, men working, not producing       10.499962
# New, under construction                   3.951244
# Permanently abandoned                     9.896046
# Temporarily closed                        9.162933

# %% [markdown]
# # Predict the Production of coal mines

# %%
for column in df.columns:
    print(column)
# Out:
# Year
# Mine_Name
# Mine_State
# Mine_County
# Mine_Status
# Mine_Type
# Company_Type
# Operation_Type
# Operating_Company
# Operating_Company_Address
# Union_Code
# Coal_Supply_Region
# Production_(short_tons)
# Average_Employees
# Labor_Hours
# log_production

# %%
df.Union_Code.unique()
# Out:
# array([' ', 'UNIT', 'United Mine Workers of America', 'INTE',
#        'International Union of Operation Engineers',
#        'Scotia Employees Association', 'Western Energy Workers'], dtype=object)

# %%
# The values are numeric
features = ['Average_Employees',
            'Labor_Hours'
           ]

# The values are non numeric
categoricals = ['Mine_State',
                'Mine_County',
                'Mine_Status',
                'Mine_Type',
                'Company_Type',
                'Operation_Type',             
                'Union_Code',
                'Coal_Supply_Region'        
           ]

target = 'log_production'

# %% [markdown]
# # Take a look at the interplay between each of the varables and the target variable

# %%
fig = plt.subplots(figsize=(14,8))
sns.set_context('poster')
sns.violinplot(y="Mine_Status",x="log_production", data=df, split=True, inner="stick");
plt.tight_layout()

# %%
fig = plt.subplots(figsize=(14,8))
sns.set_context('poster')
sns.violinplot(y="Company_Type",x="log_production", data=df, split=True, inner="stick");
plt.tight_layout()

# %%
fig = plt.subplots(figsize=(14,8))
sns.set_context('poster')
sns.violinplot(y="Operation_Type",x="log_production", data=df, split=True, inner="stick");
plt.tight_layout()

# %%
fig = plt.subplots(figsize=(14,8))
sns.set_context('poster')
sns.violinplot(y="Coal_Supply_Region",x="log_production", data=df, split=True, inner="stick");
plt.tight_layout()

# %%
df['Company_Type'].unique()
# Out:
# array(['Independent Producer Operator', 'Operating Subsidiary',
#        'Contractor'], dtype=object)

# %% [markdown]
# ### Company_Type is a categorical value, turning this to 1,2,3 will bring ordering into the algorithm's work flow(3 is greater 2 etc..), and it is not wanted, so  use 'dummy varables'

# %%
pd.get_dummies(df['Company_Type']).sample(50).head()
# Out:
#          Contractor  Independent Producer Operator  Operating Subsidiary
# MSHA ID
# 2902170           0                              0                     1
# 3608613           0                              1                     0
# 3304565           0                              1                     0
# 4607165           0                              0                     1
# 3608034           0                              1                     0

# %%
dummy_categoricals = []
for categorical in categoricals:
    print (categorical, len(df[categorical].unique()))
    # Avoid the dummy variable trap!
    drop_var= sorted(df[categorical].unique())[-1]
    temp_df = pd.get_dummies(df[categorical],prefix=categorical)
    df=pd.concat([df,temp_df],axis=1)
    temp_df.drop('_'.join([categorical, str(drop_var)]), axis=1, inplace=True)
    dummy_categoricals += temp_df.columns.tolist()
# Out:
# Mine_State 29
# Mine_County 164
# Mine_Status 5
# Mine_Type 3
# Company_Type 3
# Operation_Type 2
# Operating_Company 752
# Union_Code 7
# Coal_Supply_Region 8

# %%
dummy_categoricals[:10]
# Out:
# ['Mine_State_Alabama',
#  'Mine_State_Alaska',
#  'Mine_State_Arizona',
#  'Mine_State_Arkansas',
#  'Mine_State_Colorado',
#  'Mine_State_Illinois',
#  'Mine_State_Indiana',
#  'Mine_State_Kansas',
#  'Mine_State_Kentucky (East)',
#  'Mine_State_Kentucky (West)']

# %% [markdown]
# # Build Model (Random Forest Prediction and Evaluation)

# %%
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
len(dummy_categoricals)
# Out:
# 964

# %%
train, test = train_test_split(df, test_size=0.3)

# %%
rf = RandomForestRegressor(n_estimators=100, oob_score=True)

# %%
rf.fit(train[features + dummy_categoricals], train[target]) #below shows params that can be adjusted as needed
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=100, n_jobs=1, oob_score=True, random_state=None,
#            verbose=0, warm_start=False)

# %%
fig=plt.subplots(figsize=(8,8))
sns.regplot(test[target], rf.predict(test[features + dummy_categoricals]))
plt.ylabel("Predicted production")
plt.xlim(0,22)
plt.ylim(0,22)
plt.tight_layout()

# %% [markdown]
# ### Look at how good this is a fit and not just look a plot and say it is good

# %%
from sklearn.metrics import explained_variance_score, r2_score, mean_squared_error

# %%
predicted = rf.predict(test[features+dummy_categoricals])
r2_score(test[target], predicted)
# Out:
# 0.86835674254133655

# %%
explained_variance_score(test[target],predicted)
# Out:
# 0.87218151017405054

# %%
mean_squared_error(test[target],predicted)
# Out:
# 0.67041119185727904

# %%
rf_importances = pd.DataFrame({'name':train[features + dummy_categoricals].columns,
                               'importance':rf.feature_importances_
                              }).sort_values(by='importance',ascending=False).reset_index(drop=True)
rf_importances.head(20)  #how predictive the items are
# Out:
#     importance                                              name
# 0     0.840086                                       Labor_Hours
# 1     0.045566                                 Average_Employees
# 2     0.005979             Coal_Supply_Region_Powder River Basin
# 3     0.005605                                 Mine_Type_Surface
# 4     0.005547             Coal_Supply_Region_Appalachia Central
# 5     0.004525  Operating_Company_Commonwealth Environmental Sys
# 6     0.004261             Operating_Company_West Fork Coal, Llc
# 7     0.003505                                Mine_Status_Active
# 8     0.002640                              Mine_County_Campbell
# 9     0.002617        Company_Type_Independent Producer Operator
# 10    0.002550              Operating_Company_Mayo Resources Inc
# 11    0.002512                 Coal_Supply_Region_Illinois Basin
# 12    0.002490               Mine_State_West Virginia (Southern)
# ...

# %% [markdown]
# ## Build Model (Multiple LinearRegression Prediction and Evaluation)

# %%
# features = X
# target = y

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
